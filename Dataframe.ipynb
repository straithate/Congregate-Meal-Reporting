# %%
import pandas as pd

# %%
df = pd.read_excel('CombinedExcelRange.xls', skiprows=2).head()

# %%
df
# Out:
#    Unnamed: 0  Full Name  Hot Lunch 01/20/2020  Boxed Lunch 01/20/2020  \
# 0           1  Doe, John                   NaN                     NaN
# 1           2  Doe, John                   NaN                     NaN
# 2           3  Doe, John                   NaN                     NaN
# 3           4  Doe, John                   NaN                     NaN
# 4           5  Doe, John                   NaN                     NaN
#
#    Alternate Lunch 01/20/2020  Ride/Boxed Lunch 01/20/2020  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    Ride/Alternate Lunch 01/20/2020  Ride/Hot Lunch 01/20/2020  \
# 0                              NaN                        NaN
# ...
